# %%
import pandas as pd
import warnings; warnings.simplefilter('ignore')
import sys
sys.path.append('..')
from id_signaling.figures import invasion_heatmaps

# %% [markdown]
# ## $\beta = 10$

# %%
disliking_df = pd.read_csv('../data/invasion/disliking/full.csv')
recept_df = pd.read_csv('../data/invasion/receptivity/full.csv')

# %%
figdir = '../../papers/idsig/Figures/'

# %%
invading_prev = 0.05
# Double checking number of trials in each.
df = disliking_df
df = df[(df.disliking == 0.2) & (df.homophily == 0.1) 
        & (df.initial_prop_churlish == invading_prev) & (df.initial_prop_covert == invading_prev)]
print(len(df.trial_idx.unique()))

df = recept_df
df = df[(df.receptivity == 0.2) & (df.homophily == 0.1) 
        & (df.initial_prop_churlish == invading_prev) & (df.initial_prop_covert == invading_prev)]

print(len(df.trial_idx.unique()))
# Out:
# 50
# 50

# %%
# print(disliking_df.disliking.unique())
disliking_df.head()
# Out:
#    K  M    S  disliking  homophily  initial_prop_churlish  \
# 0  3  1  0.5        0.0        0.0                   0.95
# 1  3  1  0.5        0.0        0.0                   0.95
# 2  3  1  0.5        0.0        0.0                   0.95
# 3  3  1  0.5        0.0        0.0                   0.95
# 4  3  1  0.5        0.0        0.0                   0.95
#
#    initial_prop_covert  prop_churlish  prop_covert  timestep   trial_idx
# 0                 0.05           0.95         0.05         0  1559630168
# 1                 0.05           0.95         0.05         1  1559630168
# 2                 0.05           0.95         0.06         2  1559630168
# 3                 0.05           0.96         0.08         3  1559630168
# 4                 0.05           0.95         0.08         4  1559630168

# %%
invasion_heatmaps(disliking_df, recept_df, invading='covert', timesteps=100,
                  save_path=f'{figdir}/covert_invades.pdf', annot=True, 
                  figsize=(10, 7),
                  invading_prev=invading_prev, 
                  cbar_label_size=13);

# %%
invasion_heatmaps(disliking_df, recept_df, invading='overt',
                  save_path=f'{figdir}/overt_invades.pdf', 
                  invading_prev=invading_prev,
                  figsize=(10, 7),
                  timesteps=100, cbar_label_size=13, annot=True);

# %%
invasion_heatmaps(disliking_df, recept_df, invading='churlish',
                  save_path=f'{figdir}/churlish_invades.pdf', 
                  invading_prev=invading_prev,
                  figsize=(10, 7),
                  timesteps=100, cbar_label_size=13, annot=True);

# %%
invasion_heatmaps(disliking_df, recept_df, invading='generous',
                  save_path=f'{figdir}/generous_invades.pdf', 
                  invading_prev=invading_prev,
                  figsize=(10, 7),
                  timesteps=100, cbar_label_size=13, annot=True);

# %% [markdown]
# ## $\beta = 1$

# %%
disliking_df = pd.read_csv('../data/invasion/disliking/full.csv')
recept_df = pd.read_csv('../data/invasion/receptivity/full.csv')

# %%
figdir = '../../papers/idsig/Figures/'

# %%
# Double checking number of trials in each.
df = disliking_df
df = df[(df.disliking == 0.1) & (df.homophily == 0.1) 
        & (df.initial_prop_churlish == 0.05) & (df.initial_prop_covert == 0.05)]
print(len(df.trial_idx.unique()))

df = recept_df
df = df[(df.receptivity == 0.1) & (df.homophily == 0.1) 
        & (df.initial_prop_churlish == 0.05) & (df.initial_prop_covert == 0.05)]

print(len(df.trial_idx.unique()))
# Out:
# 50
# 50

# %%
disliking_df.head()
# Out:
#    K  M    S  disliking  homophily  initial_prop_churlish  \
# 0  3  1  0.5        0.0        0.0                   0.05
# 1  3  1  0.5        0.0        0.0                   0.05
# 2  3  1  0.5        0.0        0.0                   0.05
# 3  3  1  0.5        0.0        0.0                   0.05
# 4  3  1  0.5        0.0        0.0                   0.05
#
#    initial_prop_covert  prop_churlish  prop_covert  timestep   trial_idx
# 0                 0.95           0.05         0.95         0  3286420471
# 1                 0.95           0.02         0.95         1  3286420471
# 2                 0.95           0.01         0.96         2  3286420471
# 3                 0.95           0.01         0.95         3  3286420471
# 4                 0.95           0.00         0.96         4  3286420471

# %%
invasion_heatmaps(disliking_df, recept_df, invading='covert',
                  save_path=f'{figdir}/covert_invades.pdf');
# Out:
# ../id_signaling/figures.py:615: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_covert > low_success_prevalence

# %%
invasion_heatmaps(disliking_df, recept_df, invading='overt',
                  save_path=f'{figdir}/overt_invades.pdf');
# Out:
# ../id_signaling/figures.py:617: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_covert < 1.0 - low_success_prevalence

# %%
invasion_heatmaps(disliking_df, recept_df, invading='churlish',
                  save_path=f'{figdir}/churlish_invades.pdf');
# Out:
# ../id_signaling/figures.py:619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_churlish > low_success_prevalence

# %%
invasion_heatmaps(disliking_df, recept_df, invading='generous',
                  save_path=f'{figdir}/generous_invades.pdf');
# Out:
# ../id_signaling/figures.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_churlish < 1.0 - low_success_prevalence
