# %%
from id_signaling.experiment import demo

# %%
param_vals = [0.1, 0.35]
df = demo(param_vals)
# Out:
# running trial with random seed 1299267082
# running trial with random seed 3543096429
# running trial with random seed 3835256473
# running trial with random seed 1982320841
# running trial with random seed 3700283448
# running trial with random seed 2500183957
# running trial with random seed 1763444342
# running trial with random seed 1272954140

# %%
df.head()
# Out:
#    timestep  trial_idx  homophily  receptivity  prop_covert  prop_churlish
# 0         0          0        0.1          0.1         0.47           0.46
# 1         1          1        0.1          0.1         0.49           0.37
# 2         2          2        0.1          0.1         0.50           0.35
# 3         3          3        0.1          0.1         0.52           0.33
# 4         4          0        0.1          0.1         0.51           0.26

# %%
from id_signaling.figures import plot_evolution

# %%
fs = (7.5, 4.5)
ax = plot_evolution(df, parameter_vals=[0.1, 0.35], figsize=fs)

# %%
plot_evolution(df, strategy='receiving', parameter_vals=[0.1, 0.35], figsize=fs) #ls='--'

# %%
df = demo(param_vals, experiment='disliking')
# Out:
# running trial with random seed 1385481638
# running trial with random seed 1263823661
# running trial with random seed 2951424484
# running trial with random seed 1588798549
# running trial with random seed 3378764137
# running trial with random seed 4078299308
# running trial with random seed 3871430964
# running trial with random seed 1879077058

# %%
df.head()
# Out:
#    timestep  trial_idx  dislike_penalty  homophily  prop_covert  prop_churlish
# 0         0          0              0.1        0.1         0.56           0.54
# 1         1          1              0.1        0.1         0.54           0.47
# 2         2          2              0.1        0.1         0.54           0.44
# 3         3          3              0.1        0.1         0.56           0.42
# 4         4          0              0.1        0.1         0.55           0.41

# %%
plot_evolution(df, experiment='disliking', strategy='signaling', 
               parameter_vals=param_vals, figsize=fs)

# %%
plot_evolution(df, experiment='disliking', strategy='receiving', 
               parameter_vals=param_vals, figsize=fs)
