# %%
import pandas as pd

from id_signaling.figures import invasion_heatmaps

# %%
disliking_df = pd.read_csv('data/invasion/disliking/full.csv')

# %%
recept_df = pd.read_csv('data/invasion/receptivity/full.csv')

# %%
# Double checking number of trials in each.
df = disliking_df
df = df[(df.disliking == 0.1) & (df.homophily == 0.1) 
        & (df.initial_prop_churlish == 0.05) & (df.initial_prop_covert == 0.05)]
print(len(df.trial_idx.unique()))

df = recept_df
df = df[(df.receptivity == 0.1) & (df.homophily == 0.1) 
        & (df.initial_prop_churlish == 0.05) & (df.initial_prop_covert == 0.05)]

print(len(df.trial_idx.unique()))
# Out:
# 100
# 100

# %%
disliking_df.head()
# Out:
#    disliking  homophily  initial_prop_churlish  initial_prop_covert  \
# 0        0.0        0.0                   0.05                  0.5
# 1        0.0        0.0                   0.05                  0.5
# 2        0.0        0.0                   0.05                  0.5
# 3        0.0        0.0                   0.05                  0.5
# 4        0.0        0.0                   0.05                  0.5
#
#    prop_churlish  prop_covert  timestep   trial_idx
# 0           0.04         0.56         0  3060858095
# 1           0.05         0.57         1  3060858095
# 2           0.04         0.56         2  3060858095
# 3           0.05         0.56         3  3060858095
# 4           0.05         0.56         4  3060858095

# %%
invasion_heatmaps(disliking_df, recept_df, invading='covert',
                  save_path='reports/Figures/covert_invades.pdf')
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_covert > low_success_prevalence
# [Text(0, 0.0, '0.0'), Text(0, 0.2, '0.2'), Text(0, 0.4, '0.4'), Text(0, 0.6000000000000001, '0.6'), Text(0, 0.8, '0.8'), Text(0, 1.0, '1.0')]
# [Text(0, 0.0, '0.0'), Text(0, 0.2, '0.2'), Text(0, 0.4, '0.4'), Text(0, 0.6000000000000001, '0.6'), Text(0, 0.8, '0.8'), Text(0, 1.0, '1.0')]
# [Text(0, 0.0, '0.0'), Text(0, 0.2, '0.2'), Text(0, 0.4, '0.4'), Text(0, 0.6000000000000001, '0.6'), Text(0, 0.8, '0.8'), Text(0, 1.0, '1.0')]
# [Text(0, 0.0, '0.0'), Text(0, 0.2, '0.2'), Text(0, 0.4, '0.4'), Text(0, 0.6000000000000001, '0.6'), Text(0, 0.8, '0.8'), Text(0, 1.0, '1.0')]
# [Text(0, 0.0, '0.0'), Text(0, 0.2, '0.2'), Text(0, 0.4, '0.4'), Text(0, 0.6000000000000001, '0.6'), Text(0, 0.8, '0.8'), Text(0, 1.0, '1.0')]
# [Text(0, 0.5, '0.0'), Text(0, 1.5, '0.1'), Text(0, 2.5, '0.2'), Text(0, 3.5, '0.30000000000000004'), Text(0, 4.5, '0.4'), Text(0, 5.5, '0.5')]

# %%
invasion_heatmaps(disliking_df, recept_df, invading='overt',
                  save_path='reports/Figures/overt_invades.pdf')
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_covert < 1.0 - low_success_prevalence

# %%
invasion_heatmaps(disliking_df, recept_df, invading='churlish',
                  save_path='reports/Figures/churlish_invades.pdf')
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:542: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_churlish > low_success_prevalence

# %%
invasion_heatmaps(disliking_df, recept_df, invading='generous',
                  save_path='reports/Figures/generous_invades.pdf')
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:544: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_churlish < 1.0 - low_success_prevalence

# %% [markdown]
# ## Some issues
