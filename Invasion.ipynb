# %%
import pandas as pd

from id_signaling.figures import invasion_heatmaps

# %%
disliking_df = pd.read_csv('data/invasion/disliking/full.csv')

# %%
recept_df = pd.read_csv('data/invasion/receptivity/full.csv')

# %%
# Double checking number of trials in each.
df = disliking_df
df = df[(df.disliking == 0.1) & (df.homophily == 0.1) 
        & (df.initial_prop_churlish == 0.05) & (df.initial_prop_covert == 0.05)]
print(len(df.trial_idx.unique()))

df = recept_df
df = df[(df.receptivity == 0.1) & (df.homophily == 0.1) 
        & (df.initial_prop_churlish == 0.05) & (df.initial_prop_covert == 0.05)]

print(len(df.trial_idx.unique()))
# Out:
# 100
# 100

# %%
disliking_df.head()
# Out:
#    disliking  homophily  initial_prop_churlish  initial_prop_covert  \
# 0        0.0        0.0                    0.5                  0.5
# 1        0.0        0.0                    0.5                  0.5
# 2        0.0        0.0                    0.5                  0.5
# 3        0.0        0.0                    0.5                  0.5
# 4        0.0        0.0                    0.5                  0.5
#
#    prop_churlish  prop_covert  timestep  trial_idx
# 0           0.50         0.50         0  752536054
# 1           0.48         0.52         1  752536054
# 2           0.49         0.53         2  752536054
# 3           0.48         0.53         3  752536054
# 4           0.49         0.52         4  752536054

# %%
invasion_heatmaps(disliking_df, recept_df, invading='covert',
                  save_path='reports/Figures/covert_invades.pdf');
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:548: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if invading == 'covert':

# %%
invasion_heatmaps(disliking_df, recept_df, invading='overt',
                  save_path='reports/Figures/overt_invades.pdf');
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:550: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   elif invading == 'overt':

# %%
invasion_heatmaps(disliking_df, recept_df, invading='churlish',
                  save_path='reports/Figures/churlish_invades.pdf');
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:552: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   elif invading == 'churlish':

# %%
invasion_heatmaps(disliking_df, recept_df, invading='generous',
                  save_path='reports/Figures/generous_invades.pdf');
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:554: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   elif invading == 'generous':

# %% [markdown]
# ## Some issues
