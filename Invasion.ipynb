# %%
import pandas as pd

from id_signaling.figures import invasion_heatmaps

# %%
disliking_df = pd.read_csv('data/invasion/disliking/full.csv')
recept_df = pd.read_csv('data/invasion/receptivity/full.csv')

# %%
invasion_heatmaps(disliking_df, recept_df, invading='covert',
                  save_path='reports/Figures/covert_invades.pdf')
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:366: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_covert > 0.0

# %%
invasion_heatmaps(disliking_df, recept_df, invading='overt',
                  save_path='reports/Figures/overt_invades.pdf')
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_covert < 1.0

# %%
invasion_heatmaps(disliking_df, recept_df, invading='generous',
                  save_path='reports/Figures/generous_invades.pdf')
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:372: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_churlish < 1.0

# %%
invasion_heatmaps(disliking_df, recept_df, invading='churlish',
                  save_path='reports/Figures/churlish_invades.pdf')
# Out:
# /Users/mt/workspace/id-sig/id_signaling/figures.py:370: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   final['success'] = final.prop_churlish > 0.0
