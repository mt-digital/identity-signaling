# %%
import pandas as pd
from id_signaling.figures import plot_evolution, heatmap, minority_diff_heatmap

# %%
df = pd.read_csv('minorities_0.1.csv')

# %%
disliking_vals = [0.1, 0.25, 0.45]
homophily_vals = disliking_vals

plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals,
               homophily_vals=homophily_vals, minority_subset='majority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/covert_series_majority.pdf')

plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals,
               homophily_vals=homophily_vals, minority_subset='minority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/covert_series_minority.pdf')

plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals, strategy='receiving',
               homophily_vals=homophily_vals,  minority_subset='majority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/churlish_series_majority.pdf')

plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals, strategy='receiving',
               homophily_vals=homophily_vals,  minority_subset='minority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/churlish_series_minority.pdf')

# %%
fs = (6, 4.75)
heatmap(df, minority_subset='minority', savefig_path='reports/Figures/minority_signalers.pdf', figsize=fs)
plt.title('Minority population')
plt.figure()
heatmap(df, minority_subset='majority', savefig_path='reports/Figures/majority_signalers.pdf')
plt.title('Majority population')
plt.figure()
heatmap(df, minority_subset='minority', strategy='receiving', savefig_path='reports/Figures/minority_receivers.pdf')
plt.title('Minority population')
plt.figure()
heatmap(df, minority_subset='majority', strategy='receiving', savefig_path='reports/Figures/majority_receivers.pdf')
plt.title('Majority population')
# Out:
# Text(0.5, 1, 'Majority population')

# %%
from id_signaling.figures import minority_diff_heatmap

minority_diff_heatmap(df, 
                      savefig_path='reports/Figures/covert_signalers_diff.pdf')

minority_diff_heatmap(df, strategy='receiving', vmin=-0.2, vmax=0.3, 
                      savefig_path='reports/Figures/churlish_receivers_diff.pdf')

# %% [markdown]
# ## Minority fraction = 0.25

# %%
df = pd.read_csv('minorities_0.25.csv')

# %%
disliking_vals = [0.1, 0.25, 0.45]
homophily_vals = disliking_vals
plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals,
               homophily_vals=homophily_vals, minority_subset='majority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/covert_series_majority_025.pdf')

plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals,
               homophily_vals=homophily_vals, minority_subset='minority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/covert_series_minority_025.pdf')

plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals, strategy='receiving',
               homophily_vals=homophily_vals,  minority_subset='majority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/churlish_series_majority_025.pdf')

plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals, strategy='receiving',
               homophily_vals=homophily_vals,  minority_subset='minority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/churlish_series_minority_025.pdf')

# %%
fs = (6, 4.75)
heatmap(df, minority_subset='minority', savefig_path='reports/Figures/minority_signalers_025.pdf', figsize=fs)
plt.title('Minority population')
plt.figure()
heatmap(df, minority_subset='majority', savefig_path='reports/Figures/majority_signalers_025.pdf')
plt.title('Majority population')
plt.figure()
heatmap(df, minority_subset='minority', strategy='receiving', savefig_path='reports/Figures/minority_receivers_025.pdf')
plt.title('Minority population')
plt.figure()
heatmap(df, minority_subset='majority', strategy='receiving', savefig_path='reports/Figures/majority_receivers_025.pdf')
plt.title('Majority population')
# Out:
# Text(0.5, 1, 'Majority population')

# %%
minority_diff_heatmap(df, vmin=-0.2, vmax=0.3, 
                      savefig_path='reports/Figures/covert_signalers_diff_025.pdf')

minority_diff_heatmap(df, strategy='receiving', vmin=-0.2, vmax=0.3, 
                      savefig_path='reports/Figures/churlish_receivers_diff_025.pdf')

# %%
df.homophily.unique()
# Out:
# array([0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.49, 0.5 ])

# %% [markdown]
# ## Minority fraction = 0.05

# %%
df = pd.read_csv('minorities_0.05.csv')

# %%
disliking_vals = [0.1, 0.25, 0.45]
homophily_vals = disliking_vals
plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals,
               homophily_vals=homophily_vals, minority_subset='majority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/covert_series_majority_005.pdf')

plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals,
               homophily_vals=homophily_vals, minority_subset='minority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/covert_series_minority_005.pdf')

plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals, strategy='receiving',
               homophily_vals=homophily_vals,  minority_subset='majority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/churlish_series_majority_005.pdf')

plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals, strategy='receiving',
               homophily_vals=homophily_vals,  minority_subset='minority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/churlish_series_minority_005.pdf')

# %%
fs = (6, 4.75)
heatmap(df, minority_subset='minority', savefig_path='reports/Figures/minority_signalers_005.pdf', figsize=fs)
plt.title('Minority population')
plt.figure()
heatmap(df, minority_subset='majority', savefig_path='reports/Figures/majority_signalers_005.pdf')
plt.title('Majority population')
plt.figure()
heatmap(df, minority_subset='minority', strategy='receiving', savefig_path='reports/Figures/minority_receivers_005.pdf')
plt.title('Minority population')
plt.figure()
heatmap(df, minority_subset='majority', strategy='receiving', savefig_path='reports/Figures/majority_receivers_005.pdf')
plt.title('Majority population')
# Out:
# Text(0.5, 1, 'Majority population')

# %%
minority_diff_heatmap(df, vmin=-0.2, vmax=0.3, 
                      savefig_path='reports/Figures/covert_signalers_diff_005.pdf')

minority_diff_heatmap(df, strategy='receiving', vmin=-0.2, vmax=0.3, 
                      savefig_path='reports/Figures/churlish_receivers_diff_005.pdf')
