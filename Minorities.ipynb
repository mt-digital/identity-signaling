# %%
from id_signaling.experiment import run_experiments

# %%
disliking_vals = [0.1, 0.3, 0.5]
homophily_vals = [0.25]

minority_trait_frac = 0.20
df_20 = run_experiments(
    disliking_vals, homophily_vals, 
    minority_trait_frac=minority_trait_frac,
    experiment='disliking',
    n_iter=100,
    n_trials=20
)
# Out:
# running trial with random seed 93207019
# running trial with random seed 3091805378
# running trial with random seed 1333334974
# running trial with random seed 326935615
# running trial with random seed 1362752441
# running trial with random seed 3304895891
# running trial with random seed 882208009
# running trial with random seed 3910091108
# running trial with random seed 1594110006
# running trial with random seed 4163295305
# running trial with random seed 1590262507
# running trial with random seed 2980621596
# running trial with random seed 831050864
# running trial with random seed 2378903783
# running trial with random seed 197530909
# running trial with random seed 3058126269
# running trial with random seed 3698725623
# running trial with random seed 963363753
# running trial with random seed 1560202871
# running trial with random seed 1016073863
# running trial with random seed 2673870242
# running trial with random seed 1949644492
# running trial with random seed 377439115
# running trial with random seed 854553940
# running trial with random seed 2932396020
# running trial with random seed 1206593807
# running trial with random seed 180293736
# running trial with random seed 3269358669
# running trial with random seed 2853464377
# running trial with random seed 923907620
# running trial with random seed 3595333068
# running trial with random seed 2393675374
# running trial with random seed 3674230148
# running trial with random seed 2397887410
# running trial with random seed 1722920547
# running trial with random seed 3239630054
# running trial with random seed 2631310204
# running trial with random seed 3109197318
# running trial with random seed 1529800112
# running trial with random seed 85604495
# running trial with random seed 938102059
# running trial with random seed 684213962
# running trial with random seed 3448762541
# running trial with random seed 4172803203
# running trial with random seed 210369793
# running trial with random seed 4213970137
# running trial with random seed 3500226970
# running trial with random seed 1961843281
# running trial with random seed 1160185053
# running trial with random seed 3874405378
# running trial with random seed 1009032261
# running trial with random seed 1034770984
# running trial with random seed 3186004151
# running trial with random seed 2552657465
# running trial with random seed 972777488
# running trial with random seed 3511914682
# running trial with random seed 3969847474
# running trial with random seed 3185596482
# running trial with random seed 3470444813
# running trial with random seed 2544191469

# %%
df_20.head()

# %%
from id_signaling.figures import plot_evolution
plot_evolution(df_20, experiment='disliking', exp_param_vals=disliking_vals,
               homophily_vals=homophily_vals, minority_subset='minority', figsize=(7.5, 4.5))

# %%
plot_evolution(df_20, experiment='disliking', exp_param_vals=disliking_vals,
               homophily_vals=homophily_vals, minority_subset='majority', figsize=(7.5, 4.5))

# %%
df = pd.read_csv('minorities_0.1.csv')
disliking_vals = [0.1, 0.25, 0.45]
homophily_vals = disliking_vals

# %%
plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals,
               homophily_vals=homophily_vals, minority_subset='majority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/covert_series_majority.pdf')

# %%
plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals,
               homophily_vals=homophily_vals, minority_subset='minority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/covert_series_minority.pdf')

# %%
plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals, strategy='receiving',
               homophily_vals=homophily_vals,  minority_subset='majority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/churlish_series_majority.pdf')

# %%
plot_evolution(df, experiment='disliking', exp_param_vals=disliking_vals, strategy='receiving',
               homophily_vals=homophily_vals,  minority_subset='minority', 
               figsize=(7.5, 4.5), savefig_path='reports/Figures/churlish_series_minority.pdf')

# %%
from id_signaling.figures import heatmap
fs = (6, 4.75)
heatmap(df, minority_subset='minority', savefig_path='reports/Figures/minority_signalers.pdf', figsize=fs)
plt.title('Minority population')
plt.figure()
heatmap(df, minority_subset='majority', savefig_path='reports/Figures/majority_signalers.pdf')
plt.title('Majority population')
plt.figure()
heatmap(df, minority_subset='minority', strategy='receiving', savefig_path='reports/Figures/minority_receivers.pdf')
plt.title('Minority population')
plt.figure()
heatmap(df, minority_subset='majority', strategy='receiving', savefig_path='reports/Figures/majority_receivers.pdf')
plt.title('Majority population')
# Out:
# Text(0.5, 1, 'Majority population')

# %%
from id_signaling.figures import minority_diff_heatmap

minority_diff_heatmap(df, 
                      savefig_path='reports/Figures/covert_signalers_diff.pdf')

# %%
minority_diff_heatmap(df, strategy='receiving', vmin=-0.2, vmax=0.3, 
                      savefig_path='reports/Figures/churlish_receivers_diff.pdf')
